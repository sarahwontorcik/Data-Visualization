# %% [markdown]
# # Online dating trends
# #### By Sarah Wontorcik
# As technology becomes more and more accessible and integrated into our daily life, dating websites and apps have become more common across the board.

# %%
library(reshape2)
library(ggplot2)
library(stringr)
library(dplyr)
library(RColorBrewer)
# Out:
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
datingdata <- read.csv("datingdata2015.csv")
head(datingdata)
# Out:
#   psraid sample int_date lang usr cregion state form sex q1 ⋯ ideo hisp
# 1 100006 1      61015    1    S   3       51    1    2   1  ⋯ 1    2
# 2 100009 1      61015    1    U   3       24    2    2   2  ⋯ 3    2
# 3 100011 1      61015    1    S   2       39    2    2   1  ⋯ 1    2
# 4 100039 1      61015    1    S   3       37    2    2   1  ⋯ 2    2
# 5 100040 1      61015    1    U   3       21    1    2   1  ⋯ 1    2
# 6 100043 1      62215    1    R   2       20    1    2   1  ⋯ 3    2
#   birth_hisp race inc ql1a qc1 zipcode weight   standwt
# 1 NA         1    99  NA   NA  20112   2.258065 0.7209406
# 2 NA         2     6  NA   NA  21239   2.548387 0.8136330
# 3 NA         1     3  NA   NA  44730   1.806452 0.5767525
# 4 NA         1     6  NA   NA  27028   5.032258 1.6066676
# 5 NA         1     3   2   NA  40511   7.161290 2.2864116
# 6 NA         1     8  NA   NA  67601   1.000000 0.3192737

# %%
tinderData <- read.csv("tinderData.csv")
head(tinderData)
# Out:
#   Question                                      Segment.Type
# 1 Have you ever met up with someone off tinder? Mobile
# 2 Have you ever met up with someone off tinder? Mobile
# 3 Have you ever met up with someone off tinder? Mobile
# 4 Have you ever met up with someone off tinder? Web
# 5 Have you ever met up with someone off tinder? Web
# 6 Have you ever met up with someone off tinder? Web
#   Segment.Description   Answer             Count Percentage
# 1 Mobile respondents    Yes                 797  0.207
# 2 Mobile respondents    No                 1969  0.511
# 3 Mobile respondents    I don't use Tinder 1090  0.283
# 4 Web-based respondents Yes                   0  0.000
# 5 Web-based respondents No                    0  0.000
# 6 Web-based respondents I don't use Tinder    0  0.000

# %%
useTinder <- tinderData %>%
    filter(Segment.Type == "University", Segment.Description == "Cornell University" | 
           Segment.Description == "University of Wisconsin-Madison" | 
           Segment.Description == "Johns Hopkins University" | 
           Segment.Description == "Northwestern University" | 
           Segment.Description == "University of California, Berkeley") %>%
    group_by(Segment.Description, Answer, Count) %>%
    summarize(
        count = n(),
    ) %>% arrange(desc(Segment.Description)) 
head(useTinder)
# Out:
#   Segment.Description                Answer             Count count
# 1 University of Wisconsin-Madison    I don't use Tinder 21    1
# 2 University of Wisconsin-Madison    No                 71    1
# 3 University of Wisconsin-Madison    Yes                34    1
# 4 University of California, Berkeley I don't use Tinder 19    1
# 5 University of California, Berkeley No                 47    1
# 6 University of California, Berkeley Yes                25    1

# %%
ggplot(useTinder, aes(reorder(Segment.Description, -Count), weight=Count, fill=Answer)) + 
    geom_bar() + 
    coord_flip() + 
    scale_fill_brewer(palette="Oranges", name="Have you ever met up 
with someone from Tinder?") +
    labs(x="University", y="Number of Students Surveyed", title="University students and Tinder dates", 
    subtitle="Dating apps like Tinder are often associated with university students,
but are students really using Tinder to go on dates?", 
    caption="Source: data.world | By Sarah Wontorcik") + 
    theme(plot.title = element_text(size = 18, face = "bold"))
# Out:
# plot without title

# %% [markdown]
# Depite the fact that dating apps like Tinder are often associated most closely with the university student demographic, this data shows that the majority of students who have used Tinder aren't using it to meet people. Out of nearly 200 students surveyed at Cornell University, less than 50 of them reported meeting up with someone from Tinder.

# %%
datingByAge <- datingdata %>% 
    filter(date1a == 1 | date2a == 1, age < 67) %>%
    group_by(age) %>%
    summarize(
        count = n(),
    )
head(datingByAge)
nrow(datingByAge)
# Out:
#   age count
# 1 18  2
# 2 19  7
# 3 20  7
# 4 21  5
# 5 22  5
# 6 23  9
# [1] 49

# %%
options(repr.plot.width=10, repr.plot.height=5)
ggplot(datingByAge, aes(x=age, weight=count)) + geom_bar() +
    labs(x="Age", y="Count", title="It's not just the Millenials though...", 
    subtitle="While people in their twenties do make up a large portion of this demographic, 
there are people in Generation X who are also taking advantage of this trend.", 
    caption="Source: Pew Research Center | By Sarah Wontorcik") +
    theme(plot.title = element_text(size = 18, face = "bold"))
# Out:
# plot without title

# %% [markdown]
# This data shows that the use of dating websites and dating apps is most common among 20 to 30 year olds, but not exclusive to that generation. The frequency of people older than 45 using dating websites and apps is much less consistent, but there are still some numbers that make the 45-to 60-year-old members of Generation X comparable to Millennials' use of online dating technology.
